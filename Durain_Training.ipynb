# %%
### https://github.com/WongKinYiu/yolov7.git
# !git clone "https://github.com/WongKinYiu/yolov7.git"
# Out:
# Cloning into 'yolov7'...
# remote: Enumerating objects: 1197, done.
# error: RPC failed; curl 92 HTTP/2 stream 0 was not closed cleanly: CANCEL (err 8)
# error: 3886 bytes of body are still expected
# fetch-pack: unexpected disconnect while reading sideband packet
# fatal: early EOF
# fatal: fetch-pack: invalid index-pack output

# %%
#### Data preprocessing
# from PIL import Image
# import os

# def convert_and_delete_webp(folder_path):
#     # Check each file in the folder
#     for filename in os.listdir(folder_path):
#         if filename.endswith('.webp'):
#             # Construct full file path
#             file_path = os.path.join(folder_path, filename)
#             # Open the .webp image
#             img = Image.open(file_path)
#             # Define the new filename, replacing .webp with .jpg
#             new_filename = filename[:-5] + '.jpg'
#             new_file_path = os.path.join(folder_path, new_filename)
#             # Convert and save the image in .jpg format
#             img.convert('RGB').save(new_file_path, 'jpeg')
#             # Delete the original .webp file
#             os.remove(file_path)
#             print(f"Converted and deleted {filename}")

# # Specify the folder path here
# folder_path = 'Durian Data/redprawn (light red) durian/'
# convert_and_delete_webp(folder_path)
# Out:
# Converted and deleted 63bd14_96f790e6bdd14aadaba0de3062e8a8dc~mv2.webp
# Converted and deleted RedPrawnb_480x480.webp
# Converted and deleted i-S7Z8Pkw-L.webp
# Converted and deleted RP.webp
# Converted and deleted durian-udang-merah.webp
# Converted and deleted Tub Tim - P1018690-L.webp
# Converted and deleted s-l1200.webp
# Converted and deleted durian-riped-fresh-peel-red-260nw-1267777654.webp
# Converted and deleted U30284c389b3f4e21a175ec2b1f05f57by.jpeg_720x720q50.webp
# Converted and deleted P1011811-1-INSTA-scaled.webp
# Converted and deleted Image 5 D13 D.webp
# Converted and deleted D13RedPrawnb8e549.webp
# Converted and deleted wheretobuyfrozenmusangkingonline_1000x1000.webp
# Converted and deleted ULB8HOG5MtoSdeJk43Owq6ya4XXao.webp
# Converted and deleted P1010190-2-feature-400px.webp
# Converted and deleted P5200338-1-L.webp
# Converted and deleted i-nQZXLsg-L.webp
# Converted and deleted 360_F_251460151_Kglv7NmKpf9YDCxPNWeFe7XAfWN5Ou2Z.webp
# ...

# %%
# !pip install -r 'yolov7/requirements.txt'

# %%
# !python 'train.py' --workers 2 --device 0 --batch-size 4 --data 'Durian_annotated_dataset/custom.yaml' --img 640 640 --cfg 'cfg/training/yolov7.yaml' --weights 'yolov7_training.pt' --name yolov7-custom --hyp "data/hyp.scratch.custom.yaml"
# Out:
# YOLOR 🚀 2023-11-3 torch 1.13.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3070, 7979.1875MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=4, bbox_interval=-1, bucket='', cache_images=False, cfg='yolov7/cfg/training/yolov7.yaml', data='Durain_annotated_dataset/custom.yaml', device='0', entity=None, epochs=300, evolve=False, exist_ok=False, freeze=[0], global_rank=-1, hyp='yolov7/data/hyp.scratch.custom.yaml', image_weights=False, img_size=[640, 640], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='yolov7-custom', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/yolov7-custom', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=4, upload_dataset=False, v5_metric=False, weights='yolov7/yolov7_training.pt', workers=2, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...
